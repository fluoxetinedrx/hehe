# %%
# mount Google Drive vào Colab
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Đọc dữ liệu từ file Numpy và Excel
path="/content/drive/MyDrive/Final Project Python/catengushitpost.npy"
post_list = np.load(path,allow_pickle=True)
post_df_full = pd.read_excel("/content/drive/MyDrive/Final Project Python/catengushitpost.xlsx")

# %%
post_df_full_new = post_df_full.drop_duplicates()
post_df_full_new = post_df_full.drop(columns=["shared_text", "video_ids", "text", "original_text", "image_lowquality", "images", "images_description", "images_lowquality_description", "images_lowquality",
                                             "video_quality", "video_duration_seconds", "video", "video_height", "video_size_MB", "video_thumbnail", "video_watches", "video_width", "post_url", "link", "links",
                                             "user_id", "username", "user_url", "is_live", "factcheck", "shared_post_id", "shared_time", "shared_user_id", "shared_username", "shared_post_url", "with", "available",
                                             "page_id", "image_ids", "videos", "sharers", "was_live", "fetched_time", "likes"])
post_df_full_new.fillna(0, inplace = True)
# Ghi DataFrame đã được xử lý trở lại vào file Excel mới
output_excel_path = "/content/drive/MyDrive/Final Project Python/catclean.xlsx"
post_df_full_new.to_excel(output_excel_path, index=False)

# %%
post_df_full_new = pd.read_excel("/content/drive/MyDrive/Final Project Python/catclean.xlsx")
post_df_full_new.head(5)
# Out:
#            post_id                                          post_text  \
# 0  378610048062267
# 1  378574944732444  Tự nhiên thèm hamburger🤤\n\nCre: Animals memep...
# 2  378549564734982                                          Nói típ i
# 3  378525251404080  Trung bình những cặp đôi:\nMột đứa hay quạo, đ...
# 4  378461914743747                                        trọn vị -))
#
#                  time   timestamp  \
# 0 2023-11-21 15:14:09  1700579649
# 1 2023-11-21 14:00:20  1700575220
# 2 2023-11-21 13:01:15  1700571675
# 3 2023-11-21 12:00:54  1700568054
# 4 2023-11-21 09:00:07  1700557207
#
#                                                image         video_id  \
# 0                                                  0  706349491428528
# 1  https://m.facebook.com/photo/view_full_size/?f...                0
# 2  https://scontent-sjc3-1.xx.fbcdn.net/v/t39.308...                0
# 3                                                  0                0
# ...

# %%
post_df_full.head(5)
# Out:
#            post_id                                               text  \
# 0  378610048062267
# 1  378574944732444  Tự nhiên thèm hamburger🤤\n\nCre: Animals memep...
# 2  378549564734982                                          Nói típ i
# 3  378525251404080  Trung bình những cặp đôi:\nMột đứa hay quạo, đ...
# 4  378461914743747                                        trọn vị -))
#
#                                            post_text  shared_text  \
# 0                                                             NaN
# 1  Tự nhiên thèm hamburger🤤\n\nCre: Animals memep...          NaN
# 2                                          Nói típ i          NaN
# 3  Trung bình những cặp đôi:\nMột đứa hay quạo, đ...          NaN
# 4                                        trọn vị -))          NaN
#
#    original_text                time   timestamp  \
# 0            NaN 2023-11-21 15:14:09  1700579649
# 1            NaN 2023-11-21 14:00:20  1700575220
# ...
